# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import FinanceDataReader as fdr

# %%
STOCK_CODE = 'ks200'

# %%
stock = fdr.DataReader(STOCK_CODE, '2021')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\dateutil\parser\_parser.py in parse(self, timestr, default, ignoretz, tzinfos, **kwargs)
#     648         try:
# --> 649             ret = self._build_naive(res, default)
#     650         except ValueError as e:
#
# ~\AppData\Roaming\Python\Python39\site-packages\dateutil\parser\_parser.py in _build_naive(self, res, default)
#    1234
# -> 1235         naive = default.replace(**repl)
#    1236
#
# ValueError: month must be in 1..12
#
# The above exception was the direct cause of the following exception:
#
# ParserError                               Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\_libs\tslib.pyx in pandas._libs.tslib.array_to_datetime()
#
# ...

# %%
stock.Close.plot()
# Out:
# <AxesSubplot:xlabel='Date'>
